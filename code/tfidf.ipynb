# %%
import pandas as pd

# %%
dt1 = pd.read_csv('processed_million2.csv')

# %%
dt1 = dt1[['stars','text']]

# %%
dt1.head()
# Out:
#    stars                                               text
# 0      1  total_bill horrible service gs these_crook act...
# 1      5  adore travis hard_rock new kelly_cardenas salo...
# 2      5  office really together organized friendly dr p...
# 3      5  lunch steak sandwich delicious caesar_salad ab...
# 4      1  today second three session pay first session w...

# %%
star5=dt1[dt1['stars']==5.0]
star4=dt1[dt1['stars']==4.0]
star3=dt1[dt1['stars']==3.0]
star2=dt1[dt1['stars']==2.0]
star1=dt1[dt1['stars']==1.0]
s_text=''
s1_text=''
s2_text=''
s3_text=''
s4_text=''
s5_text=''
len(star1)
# Out:
# 149088

# %%
for i in range(len(dt1)):
    if (int(dt1.iat[i,0])== 1):
        s1_text+=str(dt1.iat[i,1])
    elif (int(dt1.iat[i,0])== 2):
        s2_text+=str(dt1.iat[i,1])
    elif (int(dt1.iat[i,0])== 3):
        s3_text+=str(dt1.iat[i,1])
    elif (int(dt1.iat[i,0])== 4):
        s4_text+=str(dt1.iat[i,1])
    else:
        s5_text+=str(dt1.iat[i,1])

# %%
from sklearn.feature_extraction.text import TfidfTransformer 
from sklearn.feature_extraction.text import CountVectorizer 
 
vectorizer = CountVectorizer(min_df=1)
 
corpus1 = [ s1_text ]
vectorizer1=CountVectorizer()
 
transformer1 = TfidfTransformer()
tfidf1 = transformer1.fit_transform(vectorizer1.fit_transform(corpus1)) 
print (tfidf1)
# Out:
#   (0, 303188)	3.3059867382677367e-06
#   (0, 303187)	3.3059867382677367e-06
#   (0, 303186)	3.3059867382677367e-06
#   (0, 303185)	3.3059867382677367e-06
#   (0, 303184)	3.3059867382677367e-06
#   (0, 303183)	3.3059867382677367e-06
#   (0, 303182)	3.3059867382677367e-06
#   (0, 303181)	3.3059867382677367e-06
#   (0, 303180)	3.3059867382677367e-06
#   (0, 303179)	3.3059867382677367e-06
#   (0, 303178)	3.3059867382677367e-06
#   (0, 303177)	3.3059867382677367e-06
#   (0, 303176)	3.3059867382677367e-06
#   (0, 303175)	3.3059867382677367e-06
#   (0, 303174)	3.3059867382677367e-06
#   (0, 303173)	3.3059867382677367e-06
#   (0, 303172)	3.3059867382677367e-06
#   (0, 303171)	3.3059867382677367e-06
#   (0, 303170)	3.3059867382677367e-06
#   (0, 303169)	3.3059867382677367e-06
#   (0, 303168)	3.3059867382677367e-06
#   (0, 303167)	3.3059867382677367e-06
#   (0, 303166)	3.3059867382677367e-06
#   (0, 303165)	3.3059867382677367e-06
#   (0, 303164)	3.3059867382677367e-06
#   :	:
#   (0, 24)	6.611973476535473e-06
#   (0, 23)	3.3059867382677367e-06
#   (0, 22)	3.3059867382677367e-06
#   (0, 21)	3.3059867382677367e-06
#   (0, 20)	3.3059867382677367e-06
#   (0, 19)	3.3059867382677367e-06
#   (0, 18)	3.3059867382677367e-06
#   (0, 17)	3.3059867382677367e-06
#   (0, 16)	3.3059867382677367e-06
#   (0, 15)	3.3059867382677367e-06
#   (0, 14)	3.3059867382677367e-06
#   (0, 13)	9.91796021480321e-06
#   (0, 12)	6.611973476535473e-06
#   (0, 11)	1.983592042960642e-05
#   (0, 10)	1.983592042960642e-05
#   (0, 9)	6.611973476535473e-06
#   (0, 8)	6.611973476535473e-06
#   (0, 7)	6.611973476535473e-06
#   (0, 6)	6.611973476535473e-06
#   (0, 5)	3.3059867382677367e-06
#   (0, 4)	0.0004595321566192154
#   (0, 3)	3.3059867382677367e-06
#   (0, 2)	9.91796021480321e-06
#   (0, 1)	9.587361540976436e-05
#   (0, 0)	9.91796021480321e-06

# %%
from sklearn.feature_extraction.text import CountVectorizer
corpus2 = [ s2_text ]
vectorizer2=CountVectorizer()
 
transformer2 = TfidfTransformer()
tfidf2 = transformer2.fit_transform(vectorizer2.fit_transform(corpus2)) 
#print (tfidf2)

# %%
corpus3 = [ s3_text ]
vectorizer3=CountVectorizer()
 
transformer3 = TfidfTransformer()
tfidf3 = transformer3.fit_transform(vectorizer3.fit_transform(corpus3)) 
#print (tfidf3)

# %%
corpus4 = [ s4_text ]
vectorizer4=CountVectorizer()
 
transformer4 = TfidfTransformer()
tfidf4 = transformer4.fit_transform(vectorizer4.fit_transform(corpus4)) 
#print (tfidf4)

# %%
corpus5 = [ s5_text ]
vectorizer5=CountVectorizer()
 
transformer5 = TfidfTransformer()
tfidf5 = transformer5.fit_transform(vectorizer5.fit_transform(corpus5)) 
#print (tfidf5)

# %%
new1=pd.DataFrame(tfidf1.A)
new2=pd.DataFrame(tfidf2.A)
new3=pd.DataFrame(tfidf3.A)
new4=pd.DataFrame(tfidf4.A)
new5=pd.DataFrame(tfidf5.A)

# %%
print (new1.loc[:,new1.loc[0,]==new1.loc[0,:].max()])
new11 = new1.loc[0,:].sort_values(axis=0, ascending=False)
new21 = new2.loc[0,:].sort_values(axis=0, ascending=False)
new31 = new3.loc[0,:].sort_values(axis=0, ascending=False)
new41 = new4.loc[0,:].sort_values(axis=0, ascending=False)
new51 = new5.loc[0,:].sort_values(axis=0, ascending=False)
# Out:
#       23153
# 0  0.353298

# %%
X1 = vectorizer1.fit_transform(corpus1)
feature_name1 = vectorizer1.get_feature_names()
print (X1)
#print (feature_name1)
#print (X1.toarray())
X2 = vectorizer2.fit_transform(corpus2)
feature_name2 = vectorizer2.get_feature_names()
X3 = vectorizer3.fit_transform(corpus3)
feature_name3 = vectorizer3.get_feature_names()
X4 = vectorizer4.fit_transform(corpus4)
feature_name4 = vectorizer4.get_feature_names()
X5 = vectorizer5.fit_transform(corpus5)
feature_name5 = vectorizer5.get_feature_names()
# Out:
#   (0, 297709)	1
#   (0, 8461)	1
#   (0, 268183)	1
#   (0, 25227)	3
#   (0, 245322)	3
#   (0, 274667)	1
#   (0, 238929)	1
#   (0, 247026)	1
#   (0, 66972)	1
#   (0, 181805)	1
#   (0, 39635)	1
#   (0, 266787)	1
#   (0, 202115)	1
#   (0, 193842)	1
#   (0, 143039)	1
#   (0, 243583)	1
#   (0, 259426)	1
#   (0, 134687)	1
#   (0, 211206)	1
#   (0, 75112)	1
#   (0, 160862)	1
#   (0, 280477)	1
#   (0, 39714)	1
#   (0, 263801)	1
#   (0, 302554)	1
#   :	:
#   (0, 101601)	586
#   (0, 56074)	45
#   (0, 229336)	894
#   (0, 105248)	12
#   (0, 277621)	63467
#   (0, 296657)	18912
#   (0, 63580)	18522
#   (0, 230203)	23659
#   (0, 259231)	530
#   (0, 280052)	6926
#   (0, 256876)	5301
#   (0, 37858)	3
#   (0, 81270)	6
#   (0, 10470)	4116
#   (0, 27262)	14
#   (0, 224592)	4024
#   (0, 28677)	14588
#   (0, 233384)	217
#   (0, 112504)	39
#   (0, 1416)	8786
#   (0, 279324)	52
#   (0, 74822)	2
#   (0, 258331)	45172
#   (0, 80754)	9786
#   (0, 282812)	101

# %%
pd.DataFrame(new11.head(20))._stat_axis.tolist()
# Out:
# [23153,
#  277621,
#  225572,
#  65200,
#  234101,
#  280711,
#  276068,
#  8674,
#  24424,
#  258331,
#  33275,
#  115046,
#  72110,
#  225460,
#  11607,
#  226450,
#  291581,
#  293669,
#  224658,
#  12071]

# %%
print (type(feature_name1))

dict1 = {}; dict2 = {}; dict3 = {}; dict4 = {}; dict5={}
for i in range(len(feature_name1)):
    dict1[i] = feature_name1[i]
for i in range(len(feature_name2)):
    dict2[i] = feature_name2[i]
for i in range(len(feature_name3)):
    dict3[i] = feature_name3[i]
for i in range(len(feature_name4)):
    dict4[i] = feature_name4[i]
for i in range(len(feature_name5)):
    dict5[i] = feature_name5[i]
    
#print (dict1)
# Out:
# <class 'list'>

# %%
top1 = {}
for i in range(100):
    no = pd.DataFrame(new11.head(100))._stat_axis.values.tolist()[i]
    word = dict1[no]
    top1[word] = [new11.loc[no,] , no]
    
print (top1)
table1 = pd.DataFrame(top1)
table1.index = ['tfidf score','index number']
print (table1)
# Out:
# {'but': [0.3532975787717199, 23153], 'tell': [0.20982106031763842, 277621], 'order': [0.20362233518338643, 225572], 'food': [0.18257311762083575, 65200], 'place': [0.1770653437148817, 234101], 'time': [0.17624876499052958, 280711], 'take': [0.1611205696762164, 276068], 'ask': [0.16003951201280286, 8674], 'call': [0.15640292660070834, 24424], 'service': [0.14933803294103018, 258331], 'come': [0.14573450739631835, 33275], 'no': [0.1270391523914143, 115046], 'good': [0.12300915455746594, 72110], 'or': [0.12159419223348734, 225460], 'back': [0.1166286001526092, 11607], 'out': [0.11162994820434839, 226450], 'very': [0.11157705241653611, 291581], 'wait': [0.1110348705914602, 293669], 'only': [0.11079353355956666, 224658], 'bad': [0.10877688164922333, 12071], 'give': [0.10873059783488759, 70748], 'make': [0.10758342043670868, 101387], 'look': [0.10311042037983244, 98929], 'try': [0.10291206117553638, 285185], 'want': [0.0991895201082469, 294386], 'leave': [0.09435616749689947, 94741], 'people': [0.08883516964399235, 231102], 'day': [0.08671603214476273, 42250], 'more': [0.0836546884251268, 108977], 'other': [0.0819025154538449, 226236], 'minute': [0.07903953093850505, 106785], 'pay': [0.07821634024067638, 230203], 'work': [0.07791549544749402, 299197], 'also': [0.07648730917656235, 4234], 'another': [0.0758062759084792, 5629], 'need': [0.07460620272248801, 111859], 'car': [0.07401112510959981, 25300], 'still': [0.07365738452860517, 271346], 'manager': [0.07156138893654343, 101931], 'really': [0.070037329050202, 244262], 'hour': [0.0698323578724294, 81608], 'know': [0.06802067713985868, 91720], 'think': [0.0672900540707015, 279681], 'never': [0.06625858620836197, 112644], 'see': [0.06583541990586371, 257073], 'table': [0.06472791434854401, 275707], 'find': [0.06457253297184543, 63155], 'well': [0.06252282119411944, 296657], 'first': [0.061233486366195015, 63580], 'restaurant': [0.061147530711000056, 248293], 'experience': [0.05627450625879341, 58988], 'customer': [0.05469093861116316, 40453], 'way': [0.054528945260988046, 295754], 'again': [0.05395039758179119, 2296], 'use': [0.053742120417280326, 289853], 'walk': [0.05351400733233985, 294037], 'eat': [0.05250237539042992, 53018], 'staff': [0.05167257271912472, 268851], 'price': [0.05115022681447842, 239116], 'drink': [0.05080971018043684, 51125], 'new': [0.05024108046145479, 113785], 'thing': [0.05014851283278329, 279588], 'rude': [0.049166634771517774, 251977], 'check': [0.04822773453784974, 28677], 'charge': [0.047827710142519346, 28164], 'room': [0.04518292075190516, 251431], 'finally': [0.044369648014291295, 63067], 'store': [0.043764652441188295, 271788], 'company': [0.04333818015195176, 34064], 'server': [0.043080313186366875, 258233], 'great': [0.0425546612949823, 73636], 'put': [0.042376138011115845, 241857], 'customer_service': [0.042376138011115845, 40481], 'nothing': [0.04200586749642986, 222192], 'location': [0.0417248586236771, 98022], 'start': [0.04043552379575269, 269829], 'review': [0.03979746835526701, 249184], 'friend': [0.039413973893627954, 67379], 'taste': [0.039397443959936614, 276799], 'same': [0.03921561468933189, 254185], 'owner': [0.03866682089077945, 227707], 'right': [0.03829655037609346, 250072], 'nice': [0.038144474986133145, 114325], 'seem': [0.038144474986133145, 257191], 'home': [0.038035377423770306, 79952], 'employee': [0.03798248163595803, 55363], 'money': [0.0378006523653533, 108078], 'sit': [0.036749348582584156, 262720], 'long': [0.03667992286108054, 98741], 'year': [0.036550989378288094, 300850], 'not_with': [0.03602864347364179, 219451], 'bring': [0.035863344136728405, 20506], 'not_back': [0.035486461648565885, 126040], 'waitress': [0.035268266523840214, 293857], 'something': [0.03490460798263076, 265755], 'business': [0.03485171219481848, 22286], 'keep': [0.034798816407006196, 90524], 'buy': [0.03473600265897911, 23447], 'someone': [0.034693024831381626, 265597], 'week': [0.034200432807379735, 296357]}
#                        but           tell          order          food  \
# tfidf score       0.353298       0.209821       0.203622      0.182573
# index number  23153.000000  277621.000000  225572.000000  65200.000000
#
#                       place           time           take         ask  \
# tfidf score        0.177065       0.176249       0.161121     0.16004
# index number  234101.000000  280711.000000  276068.000000  8674.00000
#
#                       call        service     ...            not_with  \
# tfidf score       0.156403       0.149338     ...            0.036029
# index number  24424.000000  258331.000000     ...       219451.000000
#
#                      bring       not_back       waitress      something  \
# tfidf score       0.035863       0.035486       0.035268       0.034905
# index number  20506.000000  126040.000000  293857.000000  265755.000000
#
#                   business          keep           buy        someone  \
# tfidf score       0.034852      0.034799      0.034736       0.034693
# index number  22286.000000  90524.000000  23447.000000  265597.000000
#
#                      week
# tfidf score        0.0342
# index number  296357.0000
#
# [2 rows x 100 columns]

# %%
top2 = {}
for i in range(20):
    no = pd.DataFrame(new21.head(20))._stat_axis.values.tolist()[i]
    word = dict2[no]
    top2[word] = [new21.loc[no,] , no]
    
print (top2)
table2 = pd.DataFrame(top2)
table2.index = ['tfidf score','index number']
print (table2)
# Out:
# {'but': [0.5001894650507409, 16754], 'food': [0.254098728274373, 47368], 'good': [0.23006433349213637, 52678], 'order': [0.2217333130592735, 161747], 'place': [0.200783323590517, 168373], 'time': [0.1486193607551054, 202425], 'service': [0.1450764627598917, 185710], 'very': [0.1376676378346065, 210205], 'come': [0.12785693647433083, 24628], 'or': [0.12013550290240914, 161656], 'take': [0.112632895383133, 199087], 'really': [0.1065161861972787, 175957], 'ask': [0.10186873765061599, 5949], 'only': [0.10101427401647621, 161031], 'try': [0.09919593372187387, 205565], 'make': [0.09623657186704827, 74555], 'more': [0.09620531100238462, 80397], 'look': [0.0903803698867244, 72652], 'no': [0.08834841368358712, 84695], 'out': [0.08585796479871628, 162462]}
#                        but          food          good          order  \
# tfidf score       0.500189      0.254099      0.230064       0.221733
# index number  16754.000000  47368.000000  52678.000000  161747.000000
#
#                       place           time        service           very  \
# tfidf score        0.200783       0.148619       0.145076       0.137668
# index number  168373.000000  202425.000000  185710.000000  210205.000000
#
#                       come             or           take         really  \
# tfidf score       0.127857       0.120136       0.112633       0.106516
# index number  24628.000000  161656.000000  199087.000000  175957.000000
#
#                       ask           only            try          make  \
# tfidf score      0.101869       0.101014       0.099196      0.096237
# index number  5949.000000  161031.000000  205565.000000  74555.000000
#
#                       more         look            no            out
# tfidf score       0.096205      0.09038      0.088348       0.085858
# index number  80397.000000  72652.00000  84695.000000  162462.000000

# %%
top3 = {}
for i in range(20):
    no = pd.DataFrame(new31.head(20))._stat_axis.values.tolist()[i]
    word = dict3[no]
    top3[word] = [new31.loc[no,] , no]
    
#print (top3)
table3 = pd.DataFrame(top3)
table3.index = ['tfidf score','index number']
print (table3)
# Out:
#                        but          good          food          place  \
# tfidf score       0.535787      0.325442      0.238469       0.211789
# index number  22440.000000  68498.000000  61329.000000  199165.000000
#
#                       order           very        service           time  \
# tfidf score        0.180109       0.150351       0.134794       0.121271
# index number  190538.000000  252537.000000  221162.000000  242687.000000
#
#                          or        really          come           more  \
# tfidf score        0.114817       0.11183      0.108013       0.107128
# index number  190422.000000  209034.00000  32779.000000  104076.000000
#
#                      great           try         also           nice  \
# tfidf score       0.106313       0.10555     0.100134       0.095528
# index number  70287.000000  246669.00000  4087.000000  108663.000000
#
#                       make          other           only         pretty
# tfidf score       0.085696       0.081277       0.081262       0.080179
# index number  96674.000000  191252.000000  189554.000000  203664.000000

# %%
top5 = {}; n=100
for i in range(n):
    no = pd.DataFrame(new51.head(n))._stat_axis.values.tolist()[i]
    word = dict5[no]
    top5[word] = [new51.loc[no,] , round(no)]
    
print (top5)
table5 = pd.DataFrame(top5)
table5.index = ['tfidf score','index number']
print (table5)
# Out:
# {'great': [0.3101046591686309, 165460], 'but': [0.29380457511972347, 54631], 'place': [0.27736241549218044, 389998], 'food': [0.23229202676955016, 145358], 'good': [0.23031377876702525, 162082], 'very': [0.21717950924206483, 508583], 'service': [0.17173385567586427, 438514], 'time': [0.15206719813319863, 486620], 'love': [0.13458263616240473, 224705], 'make': [0.13383982797410304, 230037], 'also': [0.13254416046893644, 10736], 'best': [0.12268998365073862, 39241], 'come': [0.11832424820722737, 77192], 'try': [0.1179536162629604, 496961], 'order': [0.11788566707317813, 371081], 'really': [0.10952173953088704, 410978], 'or': [0.10507570049945128, 370866], 'take': [0.09719822738401059, 474753], 'nice': [0.09649711528943891, 256974], 'staff': [0.09172214040746622, 459614], 'delicious': [0.09094072472497006, 99965], 'back': [0.08912153959852638, 28411], 'friendly': [0.08811002325063114, 150628], 'work': [0.08790926428081987, 525357], 'look': [0.0840824894562635, 223417], 'definitely': [0.08123943358378234, 97915], 'more': [0.08024336023356488, 245835], 'well': [0.07767982261905174, 518693], 'out': [0.07603205476683153, 372937], 'find': [0.07467924817025713, 140768], 'restaurant': [0.073820617499372, 419249], 'want': [0.07238441871533753, 514638], 'give': [0.07086791634337854, 159886], 'experience': [0.0701281967546124, 131074], 'everything': [0.07009885505902459, 128354], 'price': [0.06905645271577376, 400384], 'day': [0.06612073885722589, 94931], 'need': [0.0656481831282855, 252696], 'other': [0.06404056707002756, 372353], 'eat': [0.06334408787475923, 117228], 'awesome': [0.063185024998678, 26458], 'know': [0.06166080112788012, 208609], 'see': [0.06118206819986862, 436056], 'amaze': [0.059609971036269596, 11525], 'only': [0.057713570921436974, 369335], 'new': [0.05747883735673457, 255349], 'fresh': [0.056754560765646216, 149450], 'people': [0.05620015714901355, 382413], 'happy': [0.05362580943612595, 172988], 'little': [0.05248457190773727, 219901], 'drink': [0.05192399109203349, 113221], 'clean': [0.05163675133522659, 72939], 'menu': [0.050699361376184734, 237955], 'amazing': [0.05064685518408025, 12499], 'friend': [0.049941110190205244, 150204], 'excellent': [0.04985771800274518, 129400], 'thing': [0.04972645252248396, 484415], 'way': [0.04863463258666421, 516007], 'think': [0.04828716513891393, 484697], 'lot': [0.04808177326979932, 224202], 'chicken': [0.047212332500539744, 68125], 'both': [0.04691737124489395, 46841], 'first': [0.045735981922543016, 141785], 'right': [0.0441036570680006, 422854], 'recommend': [0.04389363229958266, 412685], 'use': [0.04382568310980038, 503662], 'perfect': [0.043575506547420186, 383231], 'wait': [0.04240183872390814, 513301], 'help': [0.042211889852471325, 178879], 'taste': [0.042145484962456826, 476482], 'visit': [0.04208062437221011, 511008], 'home': [0.04202657388033784, 185623], 'call': [0.041410398272994024, 56937], 'year': [0.04101196893290704, 529403], 'tell': [0.04089769075009139, 478711], 'pizza': [0.04050852720861108, 389483], 'ask': [0.04012862946573745, 22322], 'location': [0.040026705681064034, 221709], 'highly_recommend': [0.03963136494051261, 181080], 'again': [0.03933177078556348, 4588], 'most': [0.03925918869647787, 247222], 'super': [0.038272381144867085, 469540], 'meal': [0.03809169807203694, 235458], 'favorite': [0.036823827962690375, 137826], 'every': [0.03670646118033917, 127061], 'enjoy': [0.03611653866904759, 122180], 'table': [0.03565324873871389, 473839], 'small': [0.03562081844359053, 448620], 'owner': [0.03553279335682713, 375350], 'bar': [0.03536292038237144, 33842], 'still': [0.03496603534205223, 463621], 'area': [0.034573783201036365, 18911], 'dish': [0.03453517570684189, 107695], 'no': [0.03453517570684189, 258796], 'everyone': [0.034507378311021866, 127708], 'few': [0.03408732877418598, 139610], 'flavor': [0.033705886731544565, 143332], 'walk': [0.03354836815523111, 514082], 'wonderful': [0.03328738149447646, 524323], 'car': [0.033230242403068634, 58728]}
#                       great           but          place           food  \
# tfidf score        0.310105      0.293805       0.277362       0.232292
# index number  165460.000000  54631.000000  389998.000000  145358.000000
#
#                        good          very        service           time  \
# tfidf score        0.230314       0.21718       0.171734       0.152067
# index number  162082.000000  508583.00000  438514.000000  486620.000000
#
#                        love          make     ...               still  \
# tfidf score        0.134583       0.13384     ...            0.034966
# index number  224705.000000  230037.00000     ...       463621.000000
#
#                       area           dish             no       everyone  \
# tfidf score       0.034574       0.034535       0.034535       0.034507
# index number  18911.000000  107695.000000  258796.000000  127708.000000
#
#                         few         flavor           walk      wonderful  \
# tfidf score        0.034087       0.033706       0.033548       0.033287
# index number  139610.000000  143332.000000  514082.000000  524323.000000
#
#                       car
# tfidf score       0.03323
# index number  58728.00000
#
# [2 rows x 100 columns]

# %%
from wordcloud import WordCloud

# %%
text5 = ' '
for i in range(999989):
    if dt1.stars.loc[i] == 5:
        text5 = text5 + str(dt1.text.loc[i])

# %%
wordcloud = WordCloud(background_color="white").generate(text5)

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
text4 = ' '
for i in range(999989):
    if dt1.stars.loc[i] == 4:
        text4 = text4 + str(dt1.text.loc[i])

# %%
wordcloud = WordCloud(background_color="white").generate(text4)

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
