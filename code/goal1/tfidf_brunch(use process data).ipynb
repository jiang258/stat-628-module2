# %%
import pandas as pd

# %%
dt1 = pd.read_csv('brunch_process.csv',encoding='utf-8')

# %%
dt1 = dt1[['stars','text']]

# %%
dt1.head()
# Out:
#    stars                                               text
# 0      1  walk friday_afternoon sit table bar walk min n...
# 1      5  pick any meat planet chef make mexican_style d...
# 2      5  flat out fantastic twice croissant bomb not_wa...
# 3      2  employee busy chat each_other employee head dr...
# 4      5  yum kale grit definitely again menu choice uni...

# %%
star5=dt1[dt1['stars']==5.0]
star4=dt1[dt1['stars']==4.0]
star3=dt1[dt1['stars']==3.0]
star2=dt1[dt1['stars']==2.0]
star1=dt1[dt1['stars']==1.0]
s_text=''
s1_text=''
s2_text=''
s3_text=''
s4_text=''
s5_text=''
len(star1)
# Out:
# 49757

# %%
for i in range(len(dt1)):
    if (int(dt1.iat[i,0])== 1):
        s1_text+=str(dt1.iat[i,1])
    elif (int(dt1.iat[i,0])== 2):
        s2_text+=str(dt1.iat[i,1])
    elif (int(dt1.iat[i,0])== 3):
        s3_text+=str(dt1.iat[i,1])
    elif (int(dt1.iat[i,0])== 4):
        s4_text+=str(dt1.iat[i,1])
    else:
        s5_text+=str(dt1.iat[i,1])

# %%
from sklearn.feature_extraction.text import TfidfTransformer 
from sklearn.feature_extraction.text import CountVectorizer 
 
#vectorizer = CountVectorizer(min_df=1)
 
corpus1 = [ s1_text ]
vectorizer1=CountVectorizer()
 
transformer1 = TfidfTransformer()
tfidf1 = transformer1.fit_transform(vectorizer1.fit_transform(corpus1)) 
print (tfidf1)
# Out:
#   (0, 129047)	0.0731186520916563
#   (0, 29472)	0.00023640042706646073
#   (0, 115194)	0.0660384593010158
#   (0, 121169)	0.17482993583700102
#   (0, 5668)	0.042847577405796006
#   (0, 46218)	0.024668384564385176
#   (0, 65568)	0.0005319009608995366
#   (0, 92091)	0.018155552798704185
#   (0, 83291)	4.728008541329214e-05
#   (0, 95428)	0.001926663480591655
#   (0, 35539)	0.03693756672913449
#   (0, 25191)	0.018628353652837104
#   (0, 98292)	0.021287858457334788
#   (0, 113344)	0.20231148548347708
#   (0, 50723)	0.001926663480591655
#   (0, 6697)	0.025838566678364157
#   (0, 69727)	0.0005910010676661518
#   (0, 78102)	5.910010676661518e-05
#   (0, 89591)	0.0013593024556321491
#   (0, 98972)	0.015318747673906655
#   (0, 42388)	0.045743482637360146
#   (0, 19749)	0.021228758350568172
#   (0, 122851)	0.05324919619672028
#   (0, 101744)	0.006902892470340653
#   (0, 113880)	0.00047280085413292145
#   :	:
#   (0, 45597)	1.1820021353323036e-05
#   (0, 125414)	1.1820021353323036e-05
# ...

# %%
corpus2 = [ s2_text ]
vectorizer2=CountVectorizer()
 
transformer2 = TfidfTransformer()
tfidf2 = transformer2.fit_transform(vectorizer2.fit_transform(corpus2)) 
#print (tfidf2)

# %%
corpus3 = [ s3_text ]
vectorizer3=CountVectorizer()
 
transformer3 = TfidfTransformer()
tfidf3 = transformer3.fit_transform(vectorizer3.fit_transform(corpus3)) 
#print (tfidf3)

# %%
corpus4 = [ s4_text ]
vectorizer4=CountVectorizer()
 
transformer4 = TfidfTransformer()
tfidf4 = transformer4.fit_transform(vectorizer4.fit_transform(corpus4)) 
#print (tfidf4)

# %%
corpus5 = [ s5_text ]
vectorizer5=CountVectorizer()
 
transformer5 = TfidfTransformer()
tfidf5 = transformer5.fit_transform(vectorizer5.fit_transform(corpus5)) 
#print (tfidf5)

# %%
new1=pd.DataFrame(tfidf1.A)
new2=pd.DataFrame(tfidf2.A)
new3=pd.DataFrame(tfidf3.A)
new4=pd.DataFrame(tfidf4.A)
new5=pd.DataFrame(tfidf5.A)

# %%
print (new1.loc[:,new1.loc[0,]==new1.loc[0,:].max()])
new11 = new1.loc[0,:].sort_values(axis=0, ascending=False)
new21 = new2.loc[0,:].sort_values(axis=0, ascending=False)
new31 = new3.loc[0,:].sort_values(axis=0, ascending=False)
new41 = new4.loc[0,:].sort_values(axis=0, ascending=False)
new51 = new5.loc[0,:].sort_values(axis=0, ascending=False)
# Out:
#       28332
# 0  0.467328

# %%
X1 = vectorizer1.fit_transform(corpus1)
feature_name1 = vectorizer1.get_feature_names()
print (X1)
#print (feature_name1)
#print (X1.toarray())
X2 = vectorizer2.fit_transform(corpus2)
feature_name2 = vectorizer2.get_feature_names()
X3 = vectorizer3.fit_transform(corpus3)
feature_name3 = vectorizer3.get_feature_names()
X4 = vectorizer4.fit_transform(corpus4)
feature_name4 = vectorizer4.get_feature_names()
X5 = vectorizer5.fit_transform(corpus5)
feature_name5 = vectorizer5.get_feature_names()
# Out:
#   (0, 109108)	1
#   (0, 62438)	1
#   (0, 71101)	1
#   (0, 4331)	1
#   (0, 45838)	1
#   (0, 88357)	1
#   (0, 37428)	1
#   (0, 2278)	1
#   (0, 54415)	1
#   (0, 99243)	1
#   (0, 74031)	1
#   (0, 12367)	1
#   (0, 55075)	1
#   (0, 130057)	1
#   (0, 91388)	1
#   (0, 125222)	1
#   (0, 34434)	1
#   (0, 57376)	1
#   (0, 129191)	1
#   (0, 54707)	1
#   (0, 43666)	1
#   (0, 15244)	1
#   (0, 15044)	1
#   (0, 125414)	1
#   (0, 45597)	1
#   :	:
#   (0, 113880)	40
#   (0, 101744)	584
#   (0, 122851)	4505
#   (0, 19749)	1796
#   (0, 42388)	3870
#   (0, 98972)	1296
#   (0, 89591)	115
#   (0, 78102)	5
#   (0, 69727)	50
#   (0, 6697)	2186
#   (0, 50723)	163
#   (0, 113344)	17116
#   (0, 98292)	1801
#   (0, 25191)	1576
#   (0, 35539)	3125
#   (0, 95428)	163
#   (0, 83291)	4
#   (0, 92091)	1536
#   (0, 65568)	45
#   (0, 46218)	2087
#   (0, 5668)	3625
#   (0, 121169)	14791
#   (0, 115194)	5587
#   (0, 29472)	20
#   (0, 129047)	6186

# %%
pd.DataFrame(new11.head(20))._stat_axis.tolist()
# Out:
# [28332,
#  113344,
#  3474,
#  14496,
#  121377,
#  128770,
#  121169,
#  123342,
#  113205,
#  5013,
#  99435,
#  46382,
#  43859,
#  128921,
#  40879,
#  22095,
#  129193,
#  44128,
#  30909,
#  102354]

# %%
print (type(feature_name1))

dict1 = {}; dict2 = {}; dict3 = {}; dict4 = {}; dict5={}
for i in range(len(feature_name1)):
    dict1[i] = feature_name1[i]
for i in range(len(feature_name2)):
    dict2[i] = feature_name2[i]
for i in range(len(feature_name3)):
    dict3[i] = feature_name3[i]
for i in range(len(feature_name4)):
    dict4[i] = feature_name4[i]
for i in range(len(feature_name5)):
    dict5[i] = feature_name5[i]
    
#print (dict1)
# Out:
# <class 'list'>

# %%
top1 = {}
for i in range(1000):
    no = pd.DataFrame(new11.head(1000))._stat_axis.values.tolist()[i]
    word = dict1[no]
    top1[word] = [new11.loc[no,] , no]
    
print (top1)
table1 = pd.DataFrame(top1)
table1.index = ['tfidf score','index number']
print (table1)
# Out:
# {'food': [0.4673281842463329, 28332], 'service': [0.20231148548347708, 113344], 'ask': [0.2011885834549114, 3474], 'come': [0.19858817875718032, 14496], 'take': [0.1871818581512236, 121377], 'wait': [0.1823474694177145, 128770], 'table': [0.17482993583700102, 121169], 'time': [0.16076411042654662, 123342], 'server': [0.13314072052383066, 113205], 'bad': [0.1262851081389033, 5013], 'only': [0.12010323697111537, 99435], 'minute': [0.11831841374676359, 46382], 'make': [0.11744373216661769, 43859], 'waitress': [0.1137558855043809, 128921], 'leave': [0.10967797813748445, 40879], 'drink': [0.1064747523507339, 22095], 'want': [0.09818891738205446, 129193], 'manager': [0.09801161706175461, 44128], 'give': [0.097952516954988, 30909], 'people': [0.09360274909696512, 102354], 'back': [0.08914660104676234, 4798], 'out': [0.08759817824947702, 100141], 'other': [0.08619159570843157, 100023], 'more': [0.08561241466211875, 47300], 'seat': [0.08129810686815583, 112543], 'taste': [0.07802396095328536,
# ...

# %%
print(table1[['food','service','nice','horrible','sad','come_back']])
print(table1[['waffle','pancake','soup','bacon','veggie','egg_benedict','tomato','potato','steak','french_toast','bread','dessert','sandwich','drink','coffee','juice']])
# Out:
#                       food        service          nice     horrible  \
# tfidf score       0.467328       0.202311      0.048498      0.04072
# index number  28332.000000  113344.000000  49758.000000  35056.00000
#
#                         sad     come_back
# tfidf score        0.015792      0.034172
# index number  110944.000000  14498.000000
#                      waffle        pancake           soup       bacon  \
# tfidf score        0.017872       0.035295       0.018356     0.03468
# index number  128692.000000  101157.000000  117268.000000  4981.00000
#
#                      veggie  egg_benedict         tomato        potato  \
# tfidf score        0.005284      0.005733       0.005863       0.02624
# index number  127621.000000  23256.000000  123928.000000  104788.00000
#
#                      steak  french_toast        bread       dessert  \
# tfidf score        0.02351      0.009952     0.024574      0.019468
# ...

# %%
top2 = {}
for i in range(700):
    no = pd.DataFrame(new21.head(700))._stat_axis.values.tolist()[i]
    word = dict2[no]
    top2[word] = [new21.loc[no,] , no]
    
print (top2)
table2 = pd.DataFrame(top2)
table2.index = ['tfidf score','index number']
print (table2)
# Out:
# {'food': [0.4955423046097726, 29852], 'service': [0.21439376830910947, 114021], 'come': [0.18570514215598058, 15430], 'time': [0.16545880775187816, 124171], 'take': [0.15694068703504607, 122263], 'table': [0.15006552728733588, 122019], 'ask': [0.14613505912274422, 3601], 'wait': [0.1389818598264134, 129680], 'make': [0.1275569620103656, 46142], 'server': [0.12638161300937836, 113874], 'only': [0.121983532876652, 99040], 'more': [0.11488088622552495, 49755], 'taste': [0.10948439135002448, 122582], 'drink': [0.10513686386250187, 23358], 'menu': [0.09554449943509005, 47946], 'other': [0.09369932788515313, 99722], 'give': [0.09357294627214376, 32709], 'want': [0.09179096552871151, 130027], 'waitress': [0.08898529371990331, 129796], 'nice': [0.08673570100833639, 52024], 'bad': [0.07994900838973276, 5181], 'price': [0.0780911986784949, 105653], 'out': [0.07739609980694331, 99870], 'minute': [0.07738346164564237, 48850], 'meal': [0.07682738254840112, 47287], 'people': [0.07675155358059549, 
# ...

# %%
print(table2[['food','service','nice','horrible','sad','come_back']])
print(table2[['waffle','pancake','soup','bacon','veggie','egg_benedict','tomato','potato','steak','french_toast','bread','dessert','sandwich','drink','coffee','juice']])
# Out:
#                       food        service          nice      horrible  \
# tfidf score       0.495542       0.214394      0.086736      0.017163
# index number  29852.000000  114021.000000  52024.000000  37100.000000
#
#                         sad     come_back
# tfidf score        0.017024      0.028436
# index number  111480.000000  15432.000000
#                      waffle        pancake           soup        bacon  \
# tfidf score        0.028272       0.042805       0.026881     0.046673
# index number  129595.000000  100968.000000  117934.000000  5138.000000
#
#                      veggie  egg_benedict         tomato         potato  \
# tfidf score        0.009213      0.009112       0.008834       0.040606
# index number  128546.000000  24585.000000  124755.000000  104887.000000
#
#                       steak  french_toast        bread       dessert  \
# tfidf score        0.028436      0.019526     0.035058      0.033478
# ...

# %%
top3 = {}
for i in range(800):
    no = pd.DataFrame(new31.head(800))._stat_axis.values.tolist()[i]
    word = dict3[no]
    top3[word] = [new31.loc[no,] , no]
    
#print (top3)
table3 = pd.DataFrame(top3)
table3.index = ['tfidf score','index number']
print (table3)
# Out:
#                       food        service          come           time  \
# tfidf score       0.471187       0.229387      0.180862       0.150748
# index number  40951.000000  142126.000000  21398.000000  155767.000000
#
#                       more          nice          make          table  \
# tfidf score       0.144864      0.134111      0.129186       0.120293
# index number  67900.000000  70884.000000  63105.000000  152806.000000
#
#                       menu        pretty     ...        take_forever  \
# tfidf score       0.118347       0.11624     ...            0.005609
# index number  65514.000000  131026.00000     ...       153183.000000
#
#                   not_which           bf     menu_item          city  \
# tfidf score        0.005609     0.005609      0.005609      0.005599
# index number  118371.000000  9967.000000  65524.000000  19838.000000
#
#               look_forward         host         sugar        patron  \
# ...

# %%
print(table3[['food','service','nice','horrible','sad','come_back']])
print(table3[['waffle','pancake','soup','bacon','veggie','egg_benedict','tomato','potato','steak','french_toast','bread','dessert','sandwich','drink','coffee','juice']])
# Out:
#                       food        service          nice      horrible  \
# tfidf score       0.471187       0.229387      0.134111      0.006928
# index number  40951.000000  142126.000000  70884.000000  51293.000000
#
#                         sad     come_back
# tfidf score        0.010364      0.036795
# index number  138840.000000  21400.000000
#                      waffle        pancake           soup        bacon  \
# tfidf score        0.038256       0.057854       0.029848     0.055605
# index number  162914.000000  124932.000000  147236.000000  7423.000000
#
#                      veggie  egg_benedict         tomato         potato  \
# tfidf score        0.012993      0.012252       0.009491       0.045716
# index number  161502.000000  33585.000000  156571.000000  130179.000000
#
#                      steak  french_toast         bread       dessert  \
# tfidf score        0.02832      0.024324      0.036956      0.048497
# ...

# %%
top4 = {}
for i in range(2000):
    no = pd.DataFrame(new41.head(2000))._stat_axis.values.tolist()[i]
    word = dict4[no]
    top4[word] = [new41.loc[no,] , no]
    
#print (top3)
table4 = pd.DataFrame(top4)
table4.index = ['tfidf score','index number']
print (table4)
# Out:
#                       food        service          come           nice  \
# tfidf score       0.421955       0.227721      0.186379       0.155037
# index number  66583.000000  201995.000000  34870.000000  113897.000000
#
#                        make     delicious           time          love  \
# tfidf score        0.153256      0.153028       0.150134      0.134531
# index number  101880.000000  46428.000000  223011.000000  99608.000000
#
#                        menu           more      ...         not_waiting  \
# tfidf score        0.130639       0.128836      ...            0.001851
# index number  105262.000000  109092.000000      ...       165679.000000
#
#                 big_enough  turkey_sandwich          vodka  wine_selection  \
# tfidf score       0.001851         0.001846       0.001846        0.001846
# index number  17289.000000    227502.000000  233602.000000   238260.000000
#
#                large_party     not_check   delectable   not_perfect  \
# ...

# %%
print(table4[['food','service','nice','sad','come_back']])
print(table4[['waffle','pancake','soup','bacon','veggie','egg_benedict','tomato','potato','steak','french_toast','bread','dessert','sandwich','drink','coffee','juice']])
# Out:
#                       food        service           nice            sad  \
# tfidf score       0.421955       0.227721       0.155037       0.005228
# index number  66583.000000  201995.000000  113897.000000  197146.000000
#
#                  come_back
# tfidf score       0.041999
# index number  34872.000000
#                      waffle        pancake           soup         bacon  \
# tfidf score        0.046266       0.067201       0.031239      0.063373
# index number  234022.000000  175611.000000  209379.000000  13341.000000
#
#                      veggie  egg_benedict         tomato         potato  \
# tfidf score        0.015185      0.015674       0.011211       0.049258
# index number  231715.000000  54991.000000  224282.000000  184091.000000
#
#                       steak  french_toast         bread       dessert  \
# tfidf score        0.027047      0.031787      0.039599      0.055816
# index number  213278.000000  68848.000000  21139.000000  47957.000000
#
# ...

# %%
top5 = {}; n=2000
for i in range(n):
    no = pd.DataFrame(new51.head(n))._stat_axis.values.tolist()[i]
    word = dict5[no]
    top5[word] = [new51.loc[no,] , round(no)]
    
print (top5)
table5 = pd.DataFrame(top5)
table5.index = ['tfidf score','index number']
print (table5)
# Out:
# {'food': [0.4749544121511817, 83797], 'service': [0.2604806494939298, 239336], 'delicious': [0.20030835513069747, 58049], 'love': [0.18562739551045557, 124756], 'come': [0.17852014164747892, 43301], 'make': [0.17225986622413164, 128209], 'best': [0.14489468842586578, 21510], 'time': [0.13512784042878734, 264976], 'nice': [0.11980448653307776, 143224], 'coffee': [0.11570871156656101, 42174], 'menu': [0.11509086739079274, 132264], 'everything': [0.10395330549383107, 74210], 'staff': [0.0981226568152233, 250855], 'fresh': [0.09715292787709695, 86800], 'amaze': [0.09100721958568019, 5722], 'sandwich': [0.09083536888778437, 234617], 'definitely': [0.09079854373823527, 55325], 'more': [0.08894501121093049, 136918], 'friendly': [0.08869132684737001, 87574], 'wait': [0.08515611249065623, 279288], 'drink': [0.08421093365222929, 65611], 'back': [0.08326166313051911, 15283], 'take': [0.08306117064964066, 259622], 'awesome': [0.0817109151661736, 14096], 'server': [0.08122809653875204, 238984], '
# ...

# %%
print(table5[['food','service','nice','sad','come_back']])
print(table5[['waffle','pancake','soup','bacon','veggie','egg_benedict','tomato','potato','steak','french_toast','bread','dessert','sandwich','drink','coffee','juice']])
# Out:
#                       food        service           nice           sad  \
# tfidf score       0.474954       0.260481       0.119804       0.00376
# index number  83797.000000  239336.000000  143224.000000  233524.00000
#
#                  come_back
# tfidf score       0.044959
# index number  43303.000000
#                      waffle        pancake           soup         bacon  \
# tfidf score        0.041572       0.062067       0.023998      0.050786
# index number  279022.000000  208561.000000  247764.000000  17517.000000
#
#                      veggie  egg_benedict         tomato         potato  \
# tfidf score        0.012463      0.015025       0.008052       0.037169
# index number  276170.000000  68630.000000  266520.000000  218624.000000
#
#                      steak  french_toast         bread       dessert  \
# tfidf score        0.02462      0.032562      0.031931      0.046883
# index number  252589.00000  86463.000000  26990.000000  60309.000000
#
# ...

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (16.0, 8.0)

plt.subplot(231)
this_item='salad'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.06, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Salad")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(232)
this_item='waffle'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.035, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Waffle")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(233)
this_item='pancake'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.05, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Pancake")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(235)
this_item='french_toast'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.03, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("French_toast")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(234)
this_item='sandwich'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.075, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Sandwich")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(236)
this_item='crepe'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.03, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Crepe")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.show()

# %%
item='meat'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# [0.02515, 0.03492, 0.03651, 0.03515, 0.02433]

# %%
item='wifi'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-ff844117263c> in <module>()
#       1 item='wifi'
# ----> 2 num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
#       3 num_list
#
# D:\Python3.7\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# D:\Python3.7\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
# ...

# %%
item='cheese'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# [0.0309, 0.0448, 0.04895, 0.05569, 0.04231]

# %%
item='taco'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# [0.0131, 0.01876, 0.02118, 0.02545, 0.02481]

# %%
item='atmosphere'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# [0.01019, 0.02461, 0.03939, 0.05078, 0.06373]

# %%
item='burger'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# [0.0447, 0.05982, 0.06754, 0.06465, 0.0478]

# %%
item='bagel'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# [0.02188, 0.02147, 0.02323, 0.02566, 0.02214]

# %%
item='omelet'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list

### We should combine 'omelet' and 'omelette' in data cleaning in next step.
# Out:
# [0.00935, 0.01534, 0.01758, 0.02151, 0.01788]

# %%
item='omelette'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# [0.01073, 0.01458, 0.01913, 0.02211, 0.02025]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (16.0, 8.0)

plt.subplot(231)
item='egg_benedict'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.025, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Egg_benedict")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(232)
item='omelette'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.035, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Omelette")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(233)
this_item='scramble_egg'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.015, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Scramble_egg")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(234)
this_item='potato'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.07, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Potato")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(235)
this_item='soup'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.06, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Soup")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(236)
this_item='bread'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.06, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Bread")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.show()

# %%
this_item='bread'
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
num_list
# Out:
# [0.02457, 0.03506, 0.03696, 0.0396, 0.03193]

# %%
this_item='soup'
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
num_list
# Out:
# [0.01836, 0.02688, 0.02985, 0.03124, 0.024]

# %%
this_item='scramble_egg'
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
num_list
# Out:
# [0.00557, 0.00708, 0.00701, 0.00722, 0.00523]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (16.0, 8.0)

plt.subplot(231)
item='dessert'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.07, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Dessert")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(232)
item='bacon'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.08, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Bacon")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(233)
this_item='steak'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.04, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Steak")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(234)
this_item='coffee'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.2, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Coffee")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(235)
this_item='juice'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.2 for c in index]
plt.ylim(ymax=0.02, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Juice")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(236)
this_item='tea'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.02, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Tea")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.show()

# %%
this_item='bacon'
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
num_list
# Out:
# [0.03468, 0.04667, 0.05561, 0.06337, 0.05079]

# %%
this_item='dessert'
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
num_list
# Out:
# [0.01947, 0.03348, 0.0485, 0.05582, 0.04688]

# %%
this_item='tea'
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
num_list
# Out:
# [0.00814, 0.01107, 0.01167, 0.01423, 0.01293]

# %%
plt.rcParams['figure.figsize'] = (16.0, 8.0)

plt.subplot(231)
this_item='come_back'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.04, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("come_back")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(232)
this_item='delicious'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.2, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("delicious")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(233)
this_item='great'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.4, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("great")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(234)
this_item='leave'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.1, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("leave")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

    
plt.subplot(235)
this_item='sad'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.015, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("sad")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(236)
this_item='disappoint'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.02, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("disappoint")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.show()

# %%
plt.rcParams['figure.figsize'] = (11.5, 8.0)

plt.subplot(221)
this_item='service'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.4, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("service")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(222)
this_item='wait'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.4, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("wait")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(223)
this_item='drink'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.2, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("drink")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(224)
this_item='food'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.9, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("food")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

    
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text5 = ' '
for i in range(len(dt1.text)-1):
    if dt1.stars.loc[i] == 5:
        text5 = text5 + str(dt1.text.loc[i])

# %%
wordcloud5 = WordCloud(background_color="white").generate(text5)

# %%
plt.imshow(wordcloud5)
plt.axis("off")
plt.show()

# %%
text4 = ' '
for i in range(len(dt1.text)-1):
    if dt1.stars.loc[i] == 4:
        text4 = text4 + str(dt1.text.loc[i])

# %%
wordcloud4 = WordCloud(background_color="white").generate(text4)

# %%
plt.imshow(wordcloud4)
plt.axis("off")
plt.show()

# %%
text3 = ' '
for i in range(len(dt1.text)-1):
    if dt1.stars.loc[i] == 3:
        text3 = text3 + str(dt1.text.loc[i])

# %%
wordcloud3 = WordCloud(background_color="white").generate(text3)

# %%
plt.imshow(wordcloud3)
plt.axis("off")
plt.show()

# %%
text2 = ' '
for i in range(len(dt1.text)-1):
    if dt1.stars.loc[i] == 2:
        text2 = text2 + str(dt1.text.loc[i])

# %%
wordcloud2 = WordCloud(background_color="white").generate(text2)

# %%
plt.imshow(wordcloud2)
plt.axis("off")
plt.show()

# %%
text1 = ' '
for i in range(len(dt1.text)-1):
    if dt1.stars.loc[i] == 1:
        text1 = text1 + str(dt1.text.loc[i])

# %%
wordcloud1 = WordCloud(background_color="white").generate(text1)

# %%
plt.imshow(wordcloud1)
plt.axis("off")
plt.show()
