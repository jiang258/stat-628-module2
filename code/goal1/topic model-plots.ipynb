# %%
import matplotlib.pyplot as plt
from scipy.stats import chisquare

# %%
each_count = [[960.9925814131275, 1328.2843373166397, 3496.237225868739, 8850.983266226016, 10998.811238230206],
              [1689.5719406921417, 1284.7484118323773, 1662.8552430979908, 2283.4284388152882, 2997.6588892871514], 
              [918.4689857484773, 1295.7542266240343, 4310.386021733284, 22691.76866887696, 65116.16578136012],
              [852.9651845563203, 952.7788115255535, 1637.955897120759, 4285.90309122391, 7956.230339686386],
              [26858.252528396435, 18794.027411567047, 16856.26991960965, 14360.265233012848, 12782.293738064356],
              [707.8646854925901, 821.4149245815352, 1499.0914032021537, 4243.456131237559, 8652.447959895246], 
              [2597.2783891782165, 2916.1684107277542, 4632.684702603146, 6838.516557862051, 7960.258679136634], 
              [3416.6151734404266, 5849.653782980517, 10787.538252899423, 20898.401485962793, 22782.15992163308],
              
              [1230.9864759137854, 1440.477577126585, 3193.842686874792, 9736.213355350308, 18129.78410829883], 
              [586.7674816185609, 477.49011693149805, 732.8324632644653, 1326.4049363527447, 1746.685144429095],
              [503.06869589164853, 554.3442636076361, 1257.6669910177588, 3440.1114963032305, 5552.4856351921335], 
              [1807.065650404431, 2974.170527455397, 7308.94364536833, 20345.974808025174, 29058.115102464333], 
              [924.6483268132433, 703.091848869808, 884.2742504756898, 1735.5245751356706, 2924.6956989755854],
    
            [752.7892233533785, 653.4437547279522, 950.9459871286526, 1958.3813630081713, 2834.8276791898534],
             [4430.913410820067, 3128.673545300029, 3519.871302687563, 4572.726834865287, 6009.664949066937]]

# %%
total_count = [49755, 44397, 64618, 132081, 214834]

# %%
score = [[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]]
not_count = [[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]]
for i in range(len(each_count)):
    for j in range(5):
        score[i].append(round(each_count[i][j]/total_count[j],5))
        not_count[i].append(total_count[j] - each_count[i][j])
        each_count[i][j] = round(each_count[i][j],4)

# %%
not_count[0]
each_count
# Out:
# [[960.9926, 1328.2843, 3496.2372, 8850.9833, 10998.8112],
#  [1689.5719, 1284.7484, 1662.8552, 2283.4284, 2997.6589],
#  [918.469, 1295.7542, 4310.386, 22691.7687, 65116.1658],
#  [852.9652, 952.7788, 1637.9559, 4285.9031, 7956.2303],
#  [26858.2525, 18794.0274, 16856.2699, 14360.2652, 12782.2937],
#  [707.8647, 821.4149, 1499.0914, 4243.4561, 8652.448],
#  [2597.2784, 2916.1684, 4632.6847, 6838.5166, 7960.2587],
#  [3416.6152, 5849.6538, 10787.5383, 20898.4015, 22782.1599],
#  [1230.9865, 1440.4776, 3193.8427, 9736.2134, 18129.7841],
#  [586.7675, 477.4901, 732.8325, 1326.4049, 1746.6851],
#  [503.0687, 554.3443, 1257.667, 3440.1115, 5552.4856],
#  [1807.0657, 2974.1705, 7308.9436, 20345.9748, 29058.1151],
#  [924.6483, 703.0918, 884.2743, 1735.5246, 2924.6957],
#  [752.7892, 653.4438, 950.946, 1958.3814, 2834.8277],
#  [4430.9134, 3128.6735, 3519.8713, 4572.7268, 6009.6649]]

# %%
topic = {13:'snooze',
0: 'coffee & good location',
1: 'wait time service',
2: 'nice service & friendly staff & amazing atmosphere',
3: 'Mexican food',
4: 'wait long time',
5: 'open at night & alcohol',
6: 'buffet & affordable price',
7: 'main courses',
14: 'meaningless, delete it',
8: 'coffee, tea & donut, pastry',
9: 'southern food & seafood',
10: 'bruschetta, bar & happy hour',
11: 'pancake waffle egg toast omelet',
12: 'bagel & cream cheese'}

# %%
topic[1]
# Out:
# 'wait time service'

# %%
plt.rcParams['figure.figsize'] = (16, 8.0)

plt.subplot(231)
this_item='service'
name_list = ['one','two','three','four','five']
num_list = score[0]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.08, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[0])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(232)
this_item='wait'
name_list = ['one','two','three','four','five']
num_list = score[1]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.04, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[1])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(233)
this_item='drink'
name_list = ['one','two','three','four','five']
num_list = score[2]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.35, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[2])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(234)
this_item='food'
name_list = ['one','two','three','four','five']
num_list = score[3]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.04, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[3])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(235)
this_item='drink'
name_list = ['one','two','three','four','five']
num_list = score[4]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.6, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[4])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(236)
this_item='food'
name_list = ['one','two','three','four','five']
num_list = score[5]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.05, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[5])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.show()

# %%
plt.rcParams['figure.figsize'] = (16, 8.0)

plt.subplot(231)
this_item='service'
name_list = ['one','two','three','four','five']
num_list = score[6]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.08, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[6])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(232)
this_item='wait'
name_list = ['one','two','three','four','five']
num_list = score[7]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.2, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[7])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(233)
this_item='drink'
name_list = ['one','two','three','four','five']
num_list = score[8]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.1, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[8])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(234)
this_item='food'
name_list = ['one','two','three','four','five']
num_list = score[9]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.015, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[9])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(235)
this_item='drink'
name_list = ['one','two','three','four','five']
num_list = score[10]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.03, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[10])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(236)
this_item='food'
name_list = ['one','two','three','four','five']
num_list = score[11]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.2, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[11])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.show()

# %%
plt.rcParams['figure.figsize'] = (16, 8.0)

plt.subplot(231)
this_item='service'
name_list = ['one','two','three','four','five']
num_list = score[12]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr') #km
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.02, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[12])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.show()

# %%
chisquare(f_obs=each_count[0],f_exp=not_count[0])
# Out:
# Power_divergenceResult(statistic=430268.16478952946, pvalue=0.0)

# %%
plt.rcParams['figure.figsize'] = (25, 9.0)

plt.subplot(241)
this_item='service'
name_list = ['one','two','three','four','five']
num_list = score[0]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.08, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[0])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(242)
this_item='wait'
name_list = ['one','two','three','four','five']
num_list = score[1]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.04, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[1])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(243)
this_item='drink'
name_list = ['one','two','three','four','five']
num_list = score[2]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.35, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[2])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(244)
this_item='food'
name_list = ['one','two','three','four','five']
num_list = score[3]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.04, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[3])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(245)
this_item='drink'
name_list = ['one','two','three','four','five']
num_list = score[4]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.6, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[4])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(246)
this_item='food'
name_list = ['one','two','three','four','five']
num_list = score[5]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.05, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[5])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(247)
this_item='service'
name_list = ['one','two','three','four','five']
num_list = score[6]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.08, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[6])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(248)
this_item='wait'
name_list = ['one','two','three','four','five']
num_list = score[7]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.2, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[7])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    

plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 7.0)

plt.subplot(231)
this_item='drink'
name_list = ['one','two','three','four','five']
num_list = score[8]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.1, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[8])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(232)
this_item='food'
name_list = ['one','two','three','four','five']
num_list = score[9]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.015, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[9])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(233)
this_item='drink'
name_list = ['one','two','three','four','five']
num_list = score[10]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.03, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[10])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(234)
this_item='food'
name_list = ['one','two','three','four','five']
num_list = score[11]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.2, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[11])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(235)
this_item='service'
name_list = ['one','two','three','four','five']
num_list = score[12]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr') #km
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.02, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("score") 
plt.title(topic[12])
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.show()
