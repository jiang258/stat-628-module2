# %%
import pandas as pd

# %%
dt1 = pd.read_csv('brunch_processed.csv',encoding='utf-8')

# %%
dt1 = dt1[['stars','text']]

# %%
dt1.head()
# Out:
#    stars                                               text
# 0      1  walk friday_afternoon sit table bar walk min o...
# 1      5  pick any meat planet chef make mexican_style d...
# 2      5  flat out fantastic twice croissant bomb not_wa...
# 3      2  employee busy chat each_other employee head dr...
# 4      5  yum kale grit definitely again menu choice uni...

# %%
star5=dt1[dt1['stars']==5.0]
star4=dt1[dt1['stars']==4.0]
star3=dt1[dt1['stars']==3.0]
star2=dt1[dt1['stars']==2.0]
star1=dt1[dt1['stars']==1.0]
s_text=''
s1_text=''
s2_text=''
s3_text=''
s4_text=''
s5_text=''
len(star1)
# Out:
# 49757

# %%
for i in range(len(dt1)):
    if (int(dt1.iat[i,0])== 1):
        s1_text+=str(dt1.iat[i,1])
    elif (int(dt1.iat[i,0])== 2):
        s2_text+=str(dt1.iat[i,1])
    elif (int(dt1.iat[i,0])== 3):
        s3_text+=str(dt1.iat[i,1])
    elif (int(dt1.iat[i,0])== 4):
        s4_text+=str(dt1.iat[i,1])
    else:
        s5_text+=str(dt1.iat[i,1])

# %%
from sklearn.feature_extraction.text import TfidfTransformer 
from sklearn.feature_extraction.text import CountVectorizer 
 
#vectorizer = CountVectorizer(min_df=1)
 
corpus1 = [ s1_text ]
vectorizer1=CountVectorizer()
 
transformer1 = TfidfTransformer()
tfidf1 = transformer1.fit_transform(vectorizer1.fit_transform(corpus1)) 
print (tfidf1)
# Out:
#   (0, 127892)	0.057217993584928295
#   (0, 28995)	0.0001845741728546074
#   (0, 114381)	0.05160693873014823
#   (0, 120146)	0.13655720178648129
#   (0, 5440)	0.03350944108175397
#   (0, 45698)	0.019278772354663742
#   (0, 98687)	0.10316773391708281
#   (0, 64704)	0.00041529188892286666
#   (0, 91060)	0.01417529647523385
#   (0, 82333)	3.691483457092148e-05
#   (0, 94383)	0.0015042795087650503
#   (0, 35245)	0.028848943217175137
#   (0, 24904)	0.014581359655513985
#   (0, 97223)	0.016620904265557398
#   (0, 112607)	0.15882607574138968
#   (0, 50015)	0.0015042795087650503
#   (0, 6456)	0.020266244179435892
#   (0, 68818)	0.0004614354321365185
#   (0, 77164)	4.614354321365185e-05
#   (0, 88571)	0.0010613014939139926
#   (0, 97902)	0.012181895408404088
#   (0, 128909)	0.05851001279491055
#   (0, 41987)	0.035982734998005715
#   (0, 19438)	0.016694733934699238
#   (0, 121772)	0.041750677899712194
#   :	:
#   (0, 68202)	9.22870864273037e-06
#   (0, 45096)	9.22870864273037e-06
#   (0, 124344)	9.22870864273037e-06
#   (0, 14848)	9.22870864273037e-06
#   (0, 15045)	9.22870864273037e-06
#   (0, 43230)	9.22870864273037e-06
#   (0, 53945)	9.22870864273037e-06
#   (0, 128031)	9.22870864273037e-06
#   (0, 56546)	9.22870864273037e-06
#   (0, 34174)	9.22870864273037e-06
#   (0, 124153)	9.22870864273037e-06
#   (0, 90369)	9.22870864273037e-06
#   (0, 128827)	9.22870864273037e-06
#   (0, 54311)	9.22870864273037e-06
#   (0, 12243)	9.22870864273037e-06
#   (0, 73104)	9.22870864273037e-06
#   (0, 98144)	9.22870864273037e-06
#   (0, 2226)	9.22870864273037e-06
#   (0, 37093)	9.22870864273037e-06
#   (0, 87348)	9.22870864273037e-06
#   (0, 45328)	9.22870864273037e-06
#   (0, 4218)	9.22870864273037e-06
#   (0, 70195)	9.22870864273037e-06
#   (0, 61583)	9.22870864273037e-06
#   (0, 108484)	9.22870864273037e-06

# %%
corpus2 = [ s2_text ]
vectorizer2=CountVectorizer()
 
transformer2 = TfidfTransformer()
tfidf2 = transformer2.fit_transform(vectorizer2.fit_transform(corpus2)) 
#print (tfidf2)

# %%
corpus3 = [ s3_text ]
vectorizer3=CountVectorizer()
 
transformer3 = TfidfTransformer()
tfidf3 = transformer3.fit_transform(vectorizer3.fit_transform(corpus3)) 
#print (tfidf3)

# %%
corpus4 = [ s4_text ]
vectorizer4=CountVectorizer()
 
transformer4 = TfidfTransformer()
tfidf4 = transformer4.fit_transform(vectorizer4.fit_transform(corpus4)) 
#print (tfidf4)

# %%
corpus5 = [ s5_text ]
vectorizer5=CountVectorizer()
 
transformer5 = TfidfTransformer()
tfidf5 = transformer5.fit_transform(vectorizer5.fit_transform(corpus5)) 
#print (tfidf5)

# %%
new1=pd.DataFrame(tfidf1.A)
new2=pd.DataFrame(tfidf2.A)
new3=pd.DataFrame(tfidf3.A)
new4=pd.DataFrame(tfidf4.A)
new5=pd.DataFrame(tfidf5.A)

# %%
print (new1.loc[:,new1.loc[0,]==new1.loc[0,:].max()])
new11 = new1.loc[0,:].sort_values(axis=0, ascending=False)
new21 = new2.loc[0,:].sort_values(axis=0, ascending=False)
new31 = new3.loc[0,:].sort_values(axis=0, ascending=False)
new41 = new4.loc[0,:].sort_values(axis=0, ascending=False)
new51 = new5.loc[0,:].sort_values(axis=0, ascending=False)
# Out:
#       27927
# 0  0.367561

# %%
X1 = vectorizer1.fit_transform(corpus1)
feature_name1 = vectorizer1.get_feature_names()
print (X1)
#print (feature_name1)
#print (X1.toarray())
X2 = vectorizer2.fit_transform(corpus2)
feature_name2 = vectorizer2.get_feature_names()
X3 = vectorizer3.fit_transform(corpus3)
feature_name3 = vectorizer3.get_feature_names()
X4 = vectorizer4.fit_transform(corpus4)
feature_name4 = vectorizer4.get_feature_names()
X5 = vectorizer5.fit_transform(corpus5)
feature_name5 = vectorizer5.get_feature_names()
# Out:
#   (0, 108484)	1
#   (0, 61583)	1
#   (0, 70195)	1
#   (0, 4218)	1
#   (0, 45328)	1
#   (0, 87348)	1
#   (0, 37093)	1
#   (0, 2226)	1
#   (0, 98144)	1
#   (0, 73104)	1
#   (0, 12243)	1
#   (0, 54311)	1
#   (0, 128827)	1
#   (0, 90369)	1
#   (0, 124153)	1
#   (0, 34174)	1
#   (0, 56546)	1
#   (0, 128031)	1
#   (0, 53945)	1
#   (0, 43230)	1
#   (0, 15045)	1
#   (0, 14848)	1
#   (0, 124344)	1
#   (0, 45096)	1
#   (0, 68202)	1
#   :	:
#   (0, 121772)	4524
#   (0, 19438)	1809
#   (0, 41987)	3899
#   (0, 128909)	6340
#   (0, 97902)	1320
#   (0, 88571)	115
#   (0, 77164)	5
#   (0, 68818)	50
#   (0, 6456)	2196
#   (0, 50015)	163
#   (0, 112607)	17210
#   (0, 97223)	1801
#   (0, 24904)	1580
#   (0, 35245)	3126
#   (0, 94383)	163
#   (0, 82333)	4
#   (0, 91060)	1536
#   (0, 64704)	45
#   (0, 98687)	11179
#   (0, 45698)	2089
#   (0, 5440)	3631
#   (0, 120146)	14797
#   (0, 114381)	5592
#   (0, 28995)	20
#   (0, 127892)	6200

# %%
pd.DataFrame(new11.head(20))._stat_axis.tolist()
# Out:
# [27927,
#  9912,
#  98734,
#  102414,
#  112607,
#  3382,
#  14324,
#  30854,
#  120351,
#  127636,
#  120146,
#  122273,
#  121024,
#  108272,
#  112471,
#  126706,
#  98687,
#  4823,
#  98333,
#  45860]

# %%
print (type(feature_name1))

dict1 = {}; dict2 = {}; dict3 = {}; dict4 = {}; dict5={}
for i in range(len(feature_name1)):
    dict1[i] = feature_name1[i]
for i in range(len(feature_name2)):
    dict2[i] = feature_name2[i]
for i in range(len(feature_name3)):
    dict3[i] = feature_name3[i]
for i in range(len(feature_name4)):
    dict4[i] = feature_name4[i]
for i in range(len(feature_name5)):
    dict5[i] = feature_name5[i]
    
#print (dict1)
# Out:
# <class 'list'>

# %%
top1 = {}
for i in range(1000):
    no = pd.DataFrame(new11.head(1000))._stat_axis.values.tolist()[i]
    word = dict1[no]
    top1[word] = [new11.loc[no,] , no]
    
print (top1)
table1 = pd.DataFrame(top1)
table1.index = ['tfidf score','index number']
print (table1)
# Out:
# {'food': [0.3675610078226652, 27927], 'but': [0.3525366701523001, 9912], 'order': [0.313932981899759, 98734], 'place': [0.20296698917956904, 102414], 'service': [0.15882607574138968, 112607], 'ask': [0.15709107851655635, 3382], 'come': [0.15537453870900853, 14324], 'good': [0.14810231629853698, 30854], 'take': [0.14669032387619924, 120351], 'wait': [0.14252817627832784, 127636], 'table': [0.13655720178648129, 120146], 'time': [0.1260180165164832, 122273], 'tell': [0.12093299805433877, 121024], 'restaurant': [0.10497656081105797, 108272], 'server': [0.10406291865542765, 112471], 'very': [0.1035276535541493, 126706], 'or': [0.10316773391708281, 98687], 'bad': [0.10020531844276635, 4823], 'only': [0.09394825398299517, 98333], 'minute': [0.09254549026930015, 45860], 'no': [0.09192716679023721, 49353], 'make': [0.09187179453838083, 43422], 'eat': [0.09156724715317073, 22629], 'waitress': [0.08891860777270712, 127778], 'look': [0.08752507276765482, 42415], 'leave': [0.08581776166874971, 40520], 'drink': [0.08324295195742794, 21725], 'try': [0.07996676038925865, 124017], 'give': [0.07693051524580037, 30405], 'want': [0.07689360041122945, 128033], 'manager': [0.07657059560873389, 43675], 'people': [0.07324826049735095, 101303], 'back': [0.06978749475632706, 4628], 'breakfast': [0.06951986220568789, 8426], 'out': [0.06859699134141484, 99130], 'other': [0.06753568984750084, 99028], 'more': [0.06694505249436611, 46756], 'seat': [0.06353043029655586, 111824], 'also': [0.06205383691371901, 1681], 'taste': [0.061195567009945086, 120663], 'think': [0.05974665975303642, 121823], 'well': [0.05851001279491055, 128909], 'still': [0.05808549219734495, 118311], 'meal': [0.057439482592353826, 44545], 'walk': [0.057217993584928295, 127892], 'cold': [0.053240420159911504, 14110], 'menu': [0.051994544493142905, 45050], 'staff': [0.05189302869807287, 117311], 'sit': [0.05160693873014823, 114381], 'serve': [0.04980734054481581, 112421], 'know': [0.049539707994176625, 39225], 'great': [0.04942896349046386, 31640], 'way': [0.04924438931760926, 128549], 'another': [0.04907827256204011, 2191], 'egg': [0.04884755484597185, 22998], 'experience': [0.048432262957048985, 25332], 'friend': [0.04806311461133977, 29052], 'first': [0.04683569636185663, 27229], 'coffee': [0.04654037768528926, 13988], 'finally': [0.04635580351243465, 27050], 'not_even': [0.0454606187740898, 64543], 'pay': [0.044962268507382365, 100965], 'waiter': [0.04466694983081499, 127684], 'bring': [0.04392865313939656, 8724], 'sandwich': [0.04333801578626182, 110893], 'customer': [0.04307961194426537, 17283], 'thing': [0.041750677899712194, 121772], 'see': [0.04167684823057035, 111970], 'hour': [0.04142767309721663, 35133], 'never': [0.040698605114440935, 48249], 'not_food': [0.04032022806008899, 66523], 'again': [0.039000522724178546, 910], 'cook': [0.03882517725996667, 15555], 'nice': [0.038243768615474655, 49049], 'day': [0.03805919444262005, 17899], 'plate': [0.03757930159319807, 102989], 'check': [0.03744087096355711, 12142], 'chicken': [0.037117866161061545, 12504], 'find': [0.03692406327956421, 27071], 'price': [0.03627805367457308, 104760], 'not_back': [0.036241138840002164, 54177], 'seem': [0.03612116562764667, 112020], 'terrible': [0.03600119241529117, 121228], 'location': [0.035982734998005715, 41987], 'burger': [0.03504140671644722, 9493], 'work': [0.03463534353616708, 130091], 'salad': [0.034570742575667966, 110583], 'arrive': [0.03456151386702524, 3081], 'bar': [0.03350944108175397, 5440], 'much': [0.033251037239757524, 47216], 'horrible': [0.03275268697305008, 34778], 'use': [0.03207899124213077, 126019], 'rude': [0.031525268723566945, 109866], 'side': [0.031469896471710564, 114051], 'something': [0.03127609359021322, 115796], 'nothing': [0.03117457779514319, 97121], 'right': [0.03070391365436394, 109114], 'husband': [0.030067132758015546, 35570], 'review': [0.029734899246877253, 108736], 'fry': [0.029707213120949063, 29388], 'new': [0.029374979609810767, 48825], 'maybe': [0.029070 ...
#                       food          but         order          place  \
# tfidf score       0.367561     0.352537      0.313933       0.202967
# index number  27927.000000  9912.000000  98734.000000  102414.000000
#
#                     service          ask          come          good  \
# tfidf score        0.158826     0.157091      0.155375      0.148102
# index number  112607.000000  3382.000000  14324.000000  30854.000000
#
#                       take           wait      ...            recently  \
# tfidf score        0.14669       0.142528      ...            0.003332
# index number  120351.00000  127636.000000      ...       107091.000000
#
#                   not_else           pork          game       bottom  \
# tfidf score       0.003332       0.003322      0.003322     0.003313
# index number  63975.000000  103830.000000  29788.000000  8065.000000
#
#                 not_cooked     min_later        website        top_off  \
# tfidf score       0.003313      0.003313       0.003313       0.003304
# index number  60436.000000  45702.000000  128728.000000  122962.000000
#
#                decide_give
# tfidf score       0.003304
# index number  18291.000000
#
# [2 rows x 1000 columns]

# %%
print(table1[['food','service','good','nice','great','horrible','sad','come_back']])
print(table1[['waffle','pancake','soup','bacon','veggie','egg_benedict','tomato','potato','steak','french_toast','bread','dessert','sandwich','drink','coffee','juice']])
# Out:
#                       food        service          good          nice  \
# tfidf score       0.367561       0.158826      0.148102      0.038244
# index number  27927.000000  112607.000000  30854.000000  49049.000000
#
#                      great      horrible           sad     come_back
# tfidf score       0.049429      0.032753       0.01245      0.026754
# index number  31640.000000  34778.000000  110274.00000  14326.000000
#                      waffle        pancake           soup        bacon  \
# tfidf score        0.014009       0.027677       0.014341     0.027123
# index number  127561.000000  100130.000000  116377.000000  4792.000000
#
#                      veggie  egg_benedict         tomato         potato  \
# tfidf score        0.004153      0.004513       0.004577       0.020497
# index number  126528.000000  23003.000000  122828.000000  104106.000000
#
#                       steak  french_toast        bread       dessert  \
# tfidf score        0.018439      0.007854     0.019214      0.015246
# index number  118037.000000  28860.000000  8363.000000  19140.000000
#
#                    sandwich         drink       coffee        juice
# tfidf score        0.043338      0.083243      0.04654      0.00395
# index number  110893.000000  21725.000000  13988.00000  38461.00000

# %%
top2 = {}
for i in range(700):
    no = pd.DataFrame(new21.head(700))._stat_axis.values.tolist()[i]
    word = dict2[no]
    top2[word] = [new21.loc[no,] , no]
    
print (top2)
table2 = pd.DataFrame(top2)
table2.index = ['tfidf score','index number']
print (table2)
# Out:
# {'but': [0.48494239772165965, 10345], 'food': [0.3510322580733948, 29379], 'order': [0.267031582160093, 98509], 'good': [0.24535570355644956, 32557], 'place': [0.20328890235796415, 102521], 'service': [0.152032450255154, 113213], 'come': [0.13044518930729, 15259], 'very': [0.12909820093944296, 127656], 'time': [0.11659424970896837, 123069], 'take': [0.11039987556998768, 121196], 'table': [0.10524232800362607, 120960], 'or': [0.10508281622322314, 98449], 'ask': [0.10250404244004234, 3490], 'wait': [0.0975325919508175, 128569], 'try': [0.0911166736723883, 124841], 'restaurant': [0.0902748059424839, 108734], 'make': [0.0896899294143398, 45722], 'server': [0.08883919991885748, 113083], 'only': [0.08582619962235757, 98044], 'breakfast': [0.08558693195175317, 8770], 'more': [0.08075726971177538, 49217], 'look': [0.07948117546855189, 44545], 'taste': [0.07702646640346227, 121502], 'eat': [0.07671630460823434, 23940], 'also': [0.07668971931150051, 1732], 'great': [0.07525411328787408, 33513], 'drink': [0.07398688081022854, 22972], 'think': [0.0684748626207493, 122631], 'well': [0.06768616548431255, 129706], 'menu': [0.0672608007365714, 47441], 'other': [0.0660910476802832, 98828], 'give': [0.0658517800096788, 32088], 'want': [0.064619994594345, 128905], 'no': [0.06353885919383621, 51702], 'waitress': [0.06245772379332743, 128681], 'nice': [0.06163357959457893, 51338], 'tell': [0.05831041750285109, 121876], 'bad': [0.05628107318550263, 4998], 'price': [0.05504928777016884, 104923], 'out': [0.054508720069914446, 98945], 'minute': [0.05434034652393357, 48321], 'meal': [0.0540213229631277, 46818], 'people': [0.05395042883850417, 101346], 'back': [0.05385294941714682, 4768], 'coffee': [0.05371116116789977, 14872], 'egg': [0.053303519951314486, 24258], 'pretty': [0.05254140811161157, 104832], 'sandwich': [0.051531166835726304, 111394], 'seem': [0.051265313868388084, 112601], 'thing': [0.05116783444703073, 122563], 'leave': [0.048943531286967566, 42653], 'way': [0.04726865759273673, 129333], 'serve': [0.04563809272639561, 113038], 'much': [0.04523045150981033, 49770], 'friend': [0.04507093972940739, 30545], 'staff': [0.044858257355536814, 118057], 'salad': [0.04484053382438093, 111056], 'side': [0.04459240438819859, 114479], 'ok': [0.04383029254849567, 97604], 'seat': [0.043715089595982436, 112383], 'little': [0.043608748409047146, 43744], 'still': [0.04352013075326774, 119051], 'chicken': [0.0429707012874354, 13187], 'however': [0.042740295382408935, 37212], 'experience': [0.04235037769697954, 26659], 'burger': [0.04211111002637514, 10003], 'first': [0.040400789269832545, 28612], 'know': [0.040347618676364896, 41364], 'maybe': [0.040223553958273726, 46628], 'again': [0.03903607737082965, 926], 'small': [0.03900063030851788, 115590], 'cold': [0.03900063030851788, 15033], 'fry': [0.03885884205927083, 30978], 'dish': [0.03869046851328995, 21709], 'another': [0.03777770665876204, 2307], 'find': [0.03756502428489145, 28428], 'sit': [0.03635096240071355, 114854], 'plate': [0.036085109433375326, 103049], 'love': [0.03563315938890034, 44911], 'star': [0.03537616818714005, 118307], 'day': [0.03524324170347094, 19050], 'see': [0.03493307990824301, 112540], 'bring': [0.03456974751954743, 9139], 'waiter': [0.034029179819293036, 128605], 'location': [0.03345316505672688, 44196], 'lot': [0.03323162091727836, 44758], 'bar': [0.033018938543407775, 5522], 'pay': [0.033010076777829835, 100992], 'buffet': [0.032992353246673954, 9688], 'bacon': [0.032797394403959255, 4960], 'cook': [0.03260243556124456, 16617], 'something': [0.03223024140697104, 116349], 'cheese': [0.0314415442705343, 12903], 'use': [0.03125544719339754, 126866], 'both': [0.03107821188183872, 8338], 'dinner': [0.030812358914500494, 20979], 'check': [0.030511058884850503, 12778], 'walk': [0.03026292944866816, 128782], 'pancake': [0.030245205917512275, 100027], 'dry': [0.030236344151934335, 23228], 'lunch': [0.03016545002731081, 45189], 'expect': [0.02950967937454318, 26557], 'review': [0.029270 ...
#                        but          food         order          good  \
# tfidf score       0.484942      0.351032      0.267032      0.245356
# index number  10345.000000  29379.000000  98509.000000  32557.000000
#
#                       place        service          come           very  \
# tfidf score        0.203289       0.152032      0.130445       0.129098
# index number  102521.000000  113213.000000  15259.000000  127656.000000
#
#                        time         take      ...              juice  \
# tfidf score        0.116594       0.1104      ...           0.004679
# index number  123069.000000  121196.0000      ...       40529.000000
#
#                      dress        avoid    few_minute      sometimes  \
# tfidf score       0.004679     0.004661      0.004661       0.004652
# index number  22938.000000  4359.000000  28145.000000  116444.000000
#
#                   wonderful           skip  not_going_not_back         often  \
# tfidf score        0.004644       0.004635            0.004635      0.004626
# index number  130892.000000  115109.000000        69318.000000  97506.000000
#
#                  not_drink
# tfidf score       0.004626
# index number  64410.000000
#
# [2 rows x 700 columns]

# %%
print(table2[['food','service','good','nice','great','horrible','sad','come_back']])
print(table2[['waffle','pancake','soup','bacon','veggie','egg_benedict','tomato','potato','steak','french_toast','bread','dessert','sandwich','drink','coffee','juice']])
# Out:
#                       food        service          good          nice  \
# tfidf score       0.351032       0.152032      0.245356      0.061634
# index number  29379.000000  113213.000000  32557.000000  51338.000000
#
#                      great      horrible            sad     come_back
# tfidf score       0.075254      0.012087       0.012043      0.020001
# index number  33513.000000  36864.000000  110769.000000  15261.000000
#                      waffle        pancake           soup        bacon  \
# tfidf score        0.019939       0.030245       0.018884     0.032797
# index number  128490.000000  100027.000000  116960.000000  4960.000000
#
#                     veggie  egg_benedict         tomato         potato  \
# tfidf score        0.00646      0.006443       0.006194       0.028508
# index number  127454.00000  24263.000000  123633.000000  104219.000000
#
#                       steak  french_toast        bread      dessert  \
# tfidf score        0.020028      0.013771     0.024609      0.02359
# index number  118751.000000  30333.000000  8702.000000  20342.00000
#
#                    sandwich         drink        coffee         juice
# tfidf score        0.051531      0.073987      0.053711      0.004679
# index number  111394.000000  22972.000000  14872.000000  40529.000000

# %%
top3 = {}
for i in range(800):
    no = pd.DataFrame(new31.head(800))._stat_axis.values.tolist()[i]
    word = dict3[no]
    top3[word] = [new31.loc[no,] , no]
    
#print (top3)
table3 = pd.DataFrame(top3)
table3.index = ['tfidf score','index number']
print (table3)
# Out:
#                        but          good         food          order  \
# tfidf score       0.528623      0.338033      0.30703       0.206837
# index number  14492.000000  44590.000000  40071.00000  121274.000000
#
#                       place        service           very          come  \
# tfidf score        0.206649       0.149123       0.144103      0.115883
# index number  126683.000000  140450.000000  159588.000000  21123.000000
#
#                      great    breakfast      ...             nicely  \
# tfidf score       0.108359      0.10702      ...           0.003698
# index number  45895.000000  12298.00000      ...       69791.000000
#
#                    not_seem        hit_or            le           skip  \
# tfidf score        0.003698      0.003692      0.003686       0.003686
# index number  106726.000000  49881.000000  57829.000000  142875.000000
#
#                      window  fried_chicken     not_more      interest  \
# tfidf score        0.003686       0.003686      0.00368      0.003674
# index number  163389.000000   41567.000000  97459.00000  53608.000000
#
#                   not_care
# tfidf score       0.003668
# index number  78457.000000
#
# [2 rows x 800 columns]

# %%
print(table3[['food','service','good','nice','great','horrible','sad','come_back']])
print(table3[['waffle','pancake','soup','bacon','veggie','egg_benedict','tomato','potato','steak','french_toast','bread','dessert','sandwich','drink','coffee','juice']])
# Out:
#                      food        service          good          nice  \
# tfidf score       0.30703       0.149123      0.338033      0.086868
# index number  40071.00000  140450.000000  44590.000000  69682.000000
#
#                      great      horrible            sad     come_back
# tfidf score       0.108359      0.004438       0.006669      0.023704
# index number  45895.000000  50719.000000  137291.000000  21125.000000
#                      waffle        pancake           soup        bacon  \
# tfidf score        0.024528       0.037108       0.019109     0.035586
# index number  160695.000000  123314.000000  145262.000000  7100.000000
#
#                      veggie  egg_benedict         tomato         potato  \
# tfidf score        0.008312      0.007863       0.006062       0.029245
# index number  159311.000000  32995.000000  154216.000000  128852.000000
#
#                       steak  french_toast         bread       dessert  \
# tfidf score        0.018145      0.015635      0.023643      0.031143
# index number  147712.000000  41298.000000  12200.000000  28127.000000
#
#                   sandwich         drink        coffee         juice
# tfidf score        0.05735      0.062958      0.055974      0.005699
# index number  138029.00000  31173.000000  20585.000000  55347.000000

# %%
top4 = {}
for i in range(2000):
    no = pd.DataFrame(new41.head(2000))._stat_axis.values.tolist()[i]
    word = dict4[no]
    top4[word] = [new41.loc[no,] , no]
    
#print (top3)
table4 = pd.DataFrame(top4)
table4.index = ['tfidf score','index number']
print (table4)
# Out:
#                        but          good          food          place  \
# tfidf score       0.417294      0.354814      0.286097       0.242039
# index number  23498.000000  70497.000000  63241.000000  174781.000000
#
#                      great          very          order       service  \
# tfidf score       0.213748       0.18423       0.179615       0.15224
# index number  72403.000000  223874.00000  166562.000000  195296.00000
#
#                  breakfast            try      ...             awhile  \
# tfidf score       0.146681       0.123991      ...           0.001231
# index number  19989.000000  218619.000000      ...       10603.000000
#
#                only_problem          messy      horchata          feta  \
# tfidf score        0.001227       0.001227      0.001227      0.001227
# index number  165605.000000  101455.000000  80390.000000  60826.000000
#
#                   few_week          shell    hidden_gem         mother  \
# tfidf score       0.001227       0.001223      0.001223       0.001223
# index number  60913.000000  196626.000000  78298.000000  105177.000000
#
#                    pudding
# tfidf score        0.00122
# index number  181247.00000
#
# [2 rows x 2000 columns]

# %%
print(table4[['food','service','good','nice','great','sad','come_back']])
print(table4[['waffle','pancake','soup','bacon','veggie','egg_benedict','tomato','potato','steak','french_toast','bread','dessert','sandwich','drink','coffee','juice']])
# Out:
#                       food       service          good           nice  \
# tfidf score       0.286097       0.15224      0.354814       0.103105
# index number  63241.000000  195296.00000  70497.000000  108779.000000
#
#                      great            sad     come_back
# tfidf score       0.213748       0.003426      0.027704
# index number  72403.000000  190754.000000  33727.000000
#                      waffle        pancake           soup         bacon  \
# tfidf score        0.030314       0.044037       0.020441      0.041353
# index number  225682.000000  169451.000000  202065.000000  12450.000000
#
#                      veggie  egg_benedict         tomato         potato  \
# tfidf score        0.009911      0.010325       0.007302       0.032138
# index number  223499.000000  52519.000000  215925.000000  178372.000000
#
#                       steak  french_toast         bread       dessert  \
# tfidf score        0.017687      0.020767      0.025865      0.036555
# index number  205682.000000  65191.000000  19837.000000  45618.000000
#
#                   sandwich         drink        coffee         juice
# tfidf score        0.06823      0.060889      0.070171      0.006676
# index number  191660.00000  49847.000000  32901.000000  86964.000000

# %%
top5 = {}; n=2000
for i in range(n):
    no = pd.DataFrame(new51.head(n))._stat_axis.values.tolist()[i]
    word = dict5[no]
    top5[word] = [new51.loc[no,] , round(no)]
    
print (top5)
table5 = pd.DataFrame(top5)
table5.index = ['tfidf score','index number']
print (table5)
# Out:
# {'food': [0.34786951974996183, 78451], 'great': [0.3183150653024433, 89420], 'place': [0.3026768889477597, 204895], 'but': [0.2801280841174286, 29139], 'good': [0.25133379880223133, 87321], 'service': [0.18920148994909855, 229026], 'very': [0.1726044638934188, 264088], 'breakfast': [0.16924417079713527, 25114], 'order': [0.14920046878922644, 195351], 'delicious': [0.14248564145372242, 54560], 'love': [0.1339913272857392, 118076], 'try': [0.12827278222214103, 257680], 'come': [0.12651345138938247, 41336], 'make': [0.12175663545531186, 120898], 'also': [0.11918242634813322, 5134], 'best': [0.10385810770338522, 19865], 'time': [0.09611244495359714, 252489], 'or': [0.09481958154294477, 195206], 'restaurant': [0.08790319421023438, 219004], 'nice': [0.08578393481103586, 134651], 'eat': [0.08472718453996811, 63728], 'coffee': [0.08326443484595608, 40369], 'menu': [0.08160876344033224, 124663], 'everything': [0.07414528468663309, 69930], 'staff': [0.06967353217718296, 239589], 'well': [0.0695929081783004, 269627], 'fresh': [0.068731959047376, 81065], 'amaze': [0.06713099678385102, 5499], 'definitely': [0.06472667396003205, 52375], 'sandwich': [0.06452799339135719, 224655], 'friendly': [0.0630249316979039, 81751], 'more': [0.06282049227216599, 129018], 'awesome': [0.0608077717286337, 13116], 'wait': [0.06047087859044589, 266514], 'drink': [0.05971646831518772, 61535], 'back': [0.058918866611956756, 14167], 'take': [0.05872306547181341, 247500], 'server': [0.057415804918503455, 228713], 'excellent': [0.057006926067027654, 70433], 'look': [0.055172730092449586, 117440], 'want': [0.05344507297353775, 267575], 'meal': [0.05335869011759215, 123349], 'egg': [0.05202839413603003, 64779], 'little': [0.05189018156651709, 115189], 'amazing': [0.05175484842553566, 6063], 'lunch': [0.05080751643866567, 119304], 'brunch': [0.050326651873901875, 26917], 'friend': [0.04956648274158067, 81556], 'taste': [0.04950601474241875, 248212], 'perfect': [0.04874872503862906, 201770], 'favorite': [0.048702654182124744, 74577], 'enjoy': [0.04789641419329922, 66576], 'table': [0.047631506768399404, 246961], 'day': [0.04759407419748965, 50613], 'both': [0.04722838677398664, 24019], 'atmosphere': [0.04629545192977425, 11397], 'spot': [0.04558423308248888, 238505], 'price': [0.04552952394039, 210668], 'find': [0.04514080108863484, 76187], 'only': [0.04462826281002433, 194310], 'pancake': [0.04392568224833351, 198501], 'give': [0.04276527255013106, 86290], 'chicken': [0.04252627998201492, 36345], 'side': [0.04235927312718678, 231844], 'serve': [0.04229880512802486, 228626], 'experience': [0.04220378398648471, 71249], 'salad': [0.04199070627515225, 223890], 'other': [0.0419532737042425, 195978], 'out': [0.04165957199402748, 196249], 'think': [0.04114991314394849, 251499], 'happy': [0.04107216857359745, 93024], 'people': [0.040461729724915275, 201308], 'dish': [0.04011331887260138, 59092], 'thing': [0.04008452458728619, 251344], 'way': [0.03969580173553102, 268281], 'visit': [0.039635333736369106, 265165], 'know': [0.039511518309513764, 109891], 'dinner': [0.037783861190601925, 58330], 'lot': [0.03769171947759329, 117808], 'bar': [0.03618289892707695, 17188], 'bacon': [0.03582009093210547, 16124], 'tasty': [0.03476622008956924, 248426], 'burger': [0.034023327528437154, 28377], 'right': [0.0337238669611591, 220975], 'fantastic': [0.033355300109124575, 73494], 'wonderful': [0.033245881824926826, 272660], 'dessert': [0.0331393429692606, 56595], 'work': [0.032422365264912184, 273170], 'see': [0.03238781212253394, 227620], 'flavor': [0.032180493268264526, 77414], 'come_back': [0.03206531612700374, 41338], 'ask': [0.031875273843923434, 10782], 'small': [0.03144623899272699, 233711], 'much': [0.031333941279997723, 130621], 'location': [0.030847317858170888, 116383], 'super': [0.030671672717748184, 244750], 'recommend': [0.03060256643299171, 216235], 'top': [0.03053346014823524, 254236], 'cheese': [0.029816482443886825, 35691], 'waffle': [0.029445036163320778, 266282], 'most': ...
#                      food         great          place           but  \
# tfidf score       0.34787      0.318315       0.302677      0.280128
# index number  78451.00000  89420.000000  204895.000000  29139.000000
#
#                       good        service           very     breakfast  \
# tfidf score       0.251334       0.189201       0.172604      0.169244
# index number  87321.000000  229026.000000  264088.000000  25114.000000
#
#                     order     delicious      ...        banana_foster  \
# tfidf score        0.1492      0.142486      ...             0.001158
# index number  195351.0000  54560.000000      ...         16913.000000
#
#                 absolute         lounge  bacon_sausage      hangover  \
# tfidf score     0.001158       0.001158       0.001158      0.001158
# index number  340.000000  118032.000000   16139.000000  92854.000000
#
#               not_know_not_how  whipped_cream        church            pig  \
# tfidf score           0.001155       0.001152      0.001152       0.001152
# index number     163296.000000  270859.000000  38188.000000  204123.000000
#
#                         tot
# tfidf score        0.001152
# index number  254823.000000
#
# [2 rows x 2000 columns]

# %%
print(table5[['food','service','good','nice','great','sad','come_back']])
print(table5[['waffle','pancake','soup','bacon','veggie','egg_benedict','tomato','potato','steak','french_toast','bread','dessert','sandwich','drink','coffee','juice']])
# Out:
#                      food        service          good           nice  \
# tfidf score       0.34787       0.189201      0.251334       0.085784
# index number  78451.00000  229026.000000  87321.000000  134651.000000
#
#                      great            sad     come_back
# tfidf score       0.318315       0.002655      0.032065
# index number  89420.000000  223638.000000  41338.000000
#                      waffle        pancake           soup        bacon  \
# tfidf score        0.029445       0.043926       0.016954      0.03582
# index number  266282.000000  198501.000000  236751.000000  16124.00000
#
#                      veggie  egg_benedict         tomato         potato  \
# tfidf score        0.008797      0.010677       0.005672       0.026229
# index number  263614.000000  64785.000000  253876.000000  209401.000000
#
#                       steak  french_toast         bread       dessert  \
# tfidf score        0.017403       0.02309      0.022543      0.033139
# index number  241130.000000   80791.00000  24956.000000  56595.000000
#
#                    sandwich         drink        coffee          juice
# tfidf score        0.064528      0.059716      0.083264       0.007343
# index number  224655.000000  61535.000000  40369.000000  107743.000000

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (16.0, 8.0)

plt.subplot(231)
this_item='food'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.4, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Food")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(232)
this_item='waffle'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.035, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Waffle")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(233)
this_item='pancake'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.05, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Pancake")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(234)
this_item='french_toast'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.03, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("French_toast")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(235)
this_item='sandwich'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.075, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Sandwich")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(236)
this_item='crepe'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.03, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Crepe")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.show()

# %%
item='egg_benedict'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# [0.00451, 0.00644, 0.00786, 0.01032, 0.01068]

# %%
item='omelet'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# [0.00732, 0.0108, 0.01126, 0.01413, 0.01263]

# %%
item='scramble_egg'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# [0.00435, 0.00497, 0.00449, 0.00471, 0.00369]

# %%
item='crepe'
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
num_list
# Out:
# [0.00903, 0.01366, 0.017, 0.02183, 0.02305]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (16.0, 8.0)

plt.subplot(231)
item='egg_benedict'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.015, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Egg_benedict")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(232)
item='omelet'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.02, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Omelet")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(233)
this_item='scramble_egg'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.008, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Scramble_egg")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(234)
this_item='potato'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.04, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Potato")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(235)
this_item='soup'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.03, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Soup")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(236)
this_item='bread'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.03, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Bread")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (16.0, 8.0)

plt.subplot(231)
item='dessert'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.04, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Dessert")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(232)
item='bacon'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[item]].iloc[0]),5),round(float(table2[[item]].iloc[0]),5),round(float(table3[[item]].iloc[0]),5),round(float(table4[[item]].iloc[0]),5),round(float(table5[[item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.05, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Bacon")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(233)
this_item='steak'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.025, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Steak")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(234)
this_item='drink'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.1, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Drink")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(235)
this_item='coffee'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.1, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Coffee")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(236)
this_item='juice'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.01, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Juice")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.show()

# %%
plt.rcParams['figure.figsize'] = (11.5, 8.0)

plt.subplot(221)
this_item='service'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.2, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Service")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(222)
this_item='good'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.4, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Good")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.subplot(223)
this_item='great'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.4, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Great")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')
    
plt.subplot(224)
this_item='sad'
name_list = ['one','two','three','four','five']
num_list = [round(float(table1[[this_item]].iloc[0]),5),round(float(table2[[this_item]].iloc[0]),5),round(float(table3[[this_item]].iloc[0]),5),round(float(table4[[this_item]].iloc[0]),5),round(float(table5[[this_item]].iloc[0]),5)]
rects=plt.bar(range(len(num_list)), num_list, color='gcbyr')
index=[0,1,2,3,4]
index=[float(c)+0.1 for c in index]
plt.ylim(ymax=0.015, ymin=0)
plt.xticks(index, name_list)
plt.ylabel("TF-IDF score") 
plt.title("Sad")
for rect in rects:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, str(height), ha='center', va='bottom')

    
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text5 = ' '
for i in range(len(dt1.text)-1):
    if dt1.stars.loc[i] == 5:
        text5 = text5 + str(dt1.text.loc[i])

# %%
wordcloud5 = WordCloud(background_color="white").generate(text5)

# %%
plt.imshow(wordcloud5)
plt.axis("off")
plt.show()

# %%
text4 = ' '
for i in range(len(dt1.text)-1):
    if dt1.stars.loc[i] == 4:
        text4 = text4 + str(dt1.text.loc[i])

# %%
wordcloud4 = WordCloud(background_color="white").generate(text4)

# %%
plt.imshow(wordcloud4)
plt.axis("off")
plt.show()

# %%
text3 = ' '
for i in range(len(dt1.text)-1):
    if dt1.stars.loc[i] == 3:
        text3 = text3 + str(dt1.text.loc[i])

# %%
wordcloud3 = WordCloud(background_color="white").generate(text3)

# %%
plt.imshow(wordcloud3)
plt.axis("off")
plt.show()

# %%
text2 = ' '
for i in range(len(dt1.text)-1):
    if dt1.stars.loc[i] == 2:
        text2 = text2 + str(dt1.text.loc[i])

# %%
wordcloud2 = WordCloud(background_color="white").generate(text2)

# %%
plt.imshow(wordcloud2)
plt.axis("off")
plt.show()

# %%
text1 = ' '
for i in range(len(dt1.text)-1):
    if dt1.stars.loc[i] == 1:
        text1 = text1 + str(dt1.text.loc[i])

# %%
wordcloud1 = WordCloud(background_color="white").generate(text1)

# %%
plt.imshow(wordcloud1)
plt.axis("off")
plt.show()
